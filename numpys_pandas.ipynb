# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('part_r_00000_CNA.csv')

# %%
df.head(5)
# Out:
#   acct_ccy             acct_id  bal_aftr_bookg  bal_aftr_bookg_nmrc  \
# 0      GBP  GB37FAKE3149785039          3239.0               323900
# 1      GBP  GB37FAKE3149785039          6283.0               628300
# 2      EUR  NL12FAKE4031529538          6279.0               627900
# 3      EUR  NL12FAKE4031529538         10849.0              1084900
# 4      EUR  NL12FAKE1845242763         11280.0              1128000
#
#    bookg_amt  bookg_amt_nmrc bookg_cdt_dbt_ind      bookg_dt_tm_cet  \
# 0     3044.0          304400              CRDT  2013-02-01 09:00:00
# 1     3044.0          304400              CRDT  2013-02-01 09:00:00
# 2     4570.0          457000              CRDT  2013-02-01 09:00:00
# 3     4570.0          457000              CRDT  2013-02-01 09:00:00
# 4     2272.0          227200              CRDT  2013-02-01 09:00:00
#
#        bookg_dt_tm_gmt                            booking_id  ...  \
# 0  2013-02-01 09:00:00  47ea75c2-f7fa-4cdb-8cc7-967e8acca048  ...
# ...
